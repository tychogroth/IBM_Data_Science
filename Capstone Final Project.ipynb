# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Introduction
# Who doesn’t love baked goods? In Stockholm, there are many bakeries and an even bigger interest in baking.\
# It could be assumed that many people in Stockholm are considering opening a bakery of their own. \
# However, it is difficult to know in which district there is a lack of bakeries and could use an additional one.
#
# ### Business Problem
# The goal with this project is to analyze and suggest which locations in Stockholm would be the most suitable for a new bakery.\
# Since the location appears to be the most important competitive advantage, knowing where to locate a bakery would be the first step towards success.
#
# ### Target Audience
# The target audience for this project consists of baking entrepreneurs and bakery chains seeking to open a new venue in an optimal location.

# %% [markdown]
# ## Data
# In order to make the analysis needed we will need two sources of data:
# * Wikipedia to get a list of all the Districts in Stockholm (https://en.wikipedia.org/wiki/Stockholm_City_Centre)
# * Foursquare to get information about Geolocation of Districts
# * Foursquare to get information about venues related to bowling
#
# Through analyzing the number of bakeries in each district we will be able to create a number of clusters, which will be the basis for the selection of location a new bakery.

# %% [markdown]
# ## Methodology
#
# In this project we'll try to find which districts are optimal to establish a new bakery in based on number of bakeries per capita in each region.
#
# We'll use k-means clustering to create a map of the various clusters of districts in which the number of bakeries vary.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium

# !conda install -c conda-forge geocoder -y
import geocoder

print("Libraries imported.")
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.3.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geocoder
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geocoder-1.38.1            |             py_1          53 KB  conda-forge
#     ratelim-0.1.6              |             py_2           6 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          59 KB
#
# The following NEW packages will be INSTALLED:
#
#     geocoder: 1.38.1-py_1 conda-forge
#     ratelim:  0.1.6-py_2  conda-forge
#
#
# Downloading and Extracting Packages
# geocoder-1.38.1      | 53 KB     | ##################################### | 100%
# ratelim-0.1.6        | 6 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## Getting the information about Districts in Stockholm

# %%
#Create dataframe from Wikipedia Site. 
df_sthlm=pd.read_html("https://en.wikipedia.org/wiki/Stockholm_City_Centre")[0]

#Removing dropping summary row, dropping columns not needed, renaming columns. 
df_sthlm=df_sthlm.drop(38)
df_sthlm = df_sthlm.drop(df_sthlm.columns[[1, 3,5]], axis=1)
df_sthlm.columns = ['District', 'Population', 'Borough']
df_sthlm.head()
# Out:
#           District  Population      Borough
# 0       Djurgården         788    Östermalm
# 1         Fredhäll        4958  Kungsholmen
# 2      Gustav Vasa       12911     Norrmalm
# 3           Gärdet       18158    Östermalm
# 4  Hedvig Eleonora       10387    Östermalm

# %% [markdown]
# ## Getting Geolocation of each District

# %%
# Defining and calling function to get coordinates of each district. 
def get_latlng(district):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Stockholm, Sweden'.format(district))
        lat_lng_coords = g.latlng
    return lat_lng_coords
coords = [ get_latlng(district) for district in df_sthlm["District"].tolist() ]

# %%
# Creating temporary dataframe to hold coordinates of each district. 
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])

# %%
# Merging the two data frames
df_sthlm['Latitude'] = df_coords['Latitude']
df_sthlm['Longitude'] = df_coords['Longitude']

# %%
#Checking that the dataframe looks OK
df_sthlm
# Out:
#                    District  Population           Borough   Latitude  \
# 0                Djurgården         788         Östermalm  59.324620
# 1                  Fredhäll        4958       Kungsholmen  59.331030
# 2               Gustav Vasa       12911          Norrmalm  59.342500
# 3                    Gärdet       18158         Östermalm  59.333610
# 4           Hedvig Eleonora       10387         Östermalm  59.335240
# 5    Hjorthagen-Värtahamnen        2225         Östermalm  59.355180
# 6                     Jakob         201          Norrmalm  59.329274
# 7                     Klara        1597          Norrmalm  59.334667
# 8              Kristineberg        5572       Kungsholmen  59.336620
# 9                 Kungsholm       18465       Kungsholmen  59.329010
# 10           Lilla Essingen        4519       Kungsholmen  59.325040
# 11              Mariatorget       14099  Maria-Gamla stan  59.318302
# 12                Marieberg        2700       Kungsholmen  59.327960
# 13        Mellersta Högalid        9914  Maria-Gamla stan  59.317260
# 14      Norra Adolf Fredrik        3816          Norrmalm  59.337890
# 15           Norra Johannes        9043          Norrmalm  59.323700
# 16            Norra Högalid       13166  Maria-Gamla stan  59.317260
# 17              Norra Sofia        7721    Katarina-Sofia  59.312150
# 18             Oscars Kyrka       15271         Östermalm  59.333300
# 19  Reimersholme-Långholmen        2349  Maria-Gamla stan  59.317850
# 20              Roslagstull        2713          Norrmalm  59.351594
# 21               Stadshagen        2258       Kungsholmen  59.336980
# 22           Stora Essingen        3954       Kungsholmen  59.320310
# 23               Storkyrkan        3017  Maria-Gamla stan  59.325630
# 24     Stureplan-Lärkstaden        8104         Östermalm  59.335578
# 25      Södra Adolf Fredrik        3703          Norrmalm  59.337890
# 26     Södra Hammarbyhamnen       10615    Katarina-Sofia  59.312360
# 27            Södra Högalid        4155    Katarina-Sofia  59.317260
# 28           Södra Johannes        2011          Norrmalm  59.323700
# 29              Södra Sofia       11015    Katarina-Sofia  59.312150
# 30            Södra Station        4844    Katarina-Sofia  59.346270
# 31       Tekniska Högskolan        3442         Östermalm  59.345700
# 32            Universitetet        3131         Östermalm  59.362910
# 33          Västra Katarina       13220    Katarina-Sofia  59.316860
# 34           Västra Matteus       14272       Kungsholmen  59.321946
# 35           Östra Katarina       19855    Katarina-Sofia  59.316860
# 36            Östra Matteus       12325       Kungsholmen  59.716670
# 37        Östra Sankt Göran       14079       Kungsholmen  59.338379
#
#     Longitude
# 0   18.097800
# 1   18.005450
# 2   18.047750
# 3   18.113360
# 4   18.080460
# 5   18.100200
# 6   18.066006
# 7   18.068028
# 8   18.004860
# 9   18.048540
# 10  18.006770
# 11  18.063466
# 12  18.018510
# 13  18.037730
# 14  18.060060
# 15  18.074492
# 16  18.037730
# 17  18.088350
# 18  18.092900
# 19  18.021540
# 20  18.055709
# 21  18.016690
# 22  17.988320
# 23  18.069820
# 24  18.073046
# 25  18.060060
# 26  18.107480
# 27  18.037730
# 28  18.074492
# 29  18.088350
# 30  18.034670
# 31  18.071940
# 32  18.058110
# 33  18.078300
# 34  18.030200
# 35  18.078300
# 36  18.100000
# 37  18.013955

# %% [markdown]
# ## Plotting the Districts to a map of Stockholm

# %%
# Getting the geolocation of Stockholm
address = 'Stockholm, Sweden'

geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geolocation of Stockholm is {}, {}.'.format(latitude, longitude))
# Out:
# The geolocation of Stockholm is 59.3251172, 18.0710935.

# %%
# Creating a map of Stockholm using geolocation.
map_sthlm = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, district in zip(df_sthlm['Latitude'], df_sthlm['Longitude'], df_sthlm['District']):
    label = '{}'.format(district)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_sthlm)  

map_sthlm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok, so far it looks really good. We have all the Districts of Stockholm plotted out onto a map.
#
# Next step is to start looking at venues in each of the Districts.

# %% [markdown]
# ## Foursquare

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Client ID and Client Secret were entered here, but hidden.

# %% [markdown]
# ### Getting the Bakeries venues within a radius of 500m from each district center

# %%
radius = 500
LIMIT = 100

# Category IDs taken from Foursquare (https://developer.foursquare.com/docs/resources/categories)
categoryId ='4bf58dd8d48988d16a941735'
venues = []

for lat, long, district in zip(df_sthlm['Latitude'], df_sthlm['Longitude'], df_sthlm['District']):
    
    # create the API request URL
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        categoryId,
        radius, 
        LIMIT)
    
    # make the GET request
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    # return only relevant information for each nearby venue
    for venue in results:
        venues.append((
            district,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
# convert the venues list into a new DataFrame
df_venues = pd.DataFrame(venues)

# define the column names
df_venues.columns = ['District', 'Latitude', 'Longitude', 'Venue Name', 'Venue Latitude', 'Venue Longitude', 'Venue Category']

print(df_venues.shape)
df_venues
# Out:
# (202, 7)
#                     District   Latitude  Longitude  \
# 0                 Djurgården  59.324620  18.097800
# 1                   Fredhäll  59.331030  18.005450
# 2                Gustav Vasa  59.342500  18.047750
# 3                Gustav Vasa  59.342500  18.047750
# 4                Gustav Vasa  59.342500  18.047750
# 5                Gustav Vasa  59.342500  18.047750
# 6                Gustav Vasa  59.342500  18.047750
# 7                Gustav Vasa  59.342500  18.047750
# 8                Gustav Vasa  59.342500  18.047750
# 9            Hedvig Eleonora  59.335240  18.080460
# 10           Hedvig Eleonora  59.335240  18.080460
# 11           Hedvig Eleonora  59.335240  18.080460
# 12           Hedvig Eleonora  59.335240  18.080460
# 13           Hedvig Eleonora  59.335240  18.080460
# 14           Hedvig Eleonora  59.335240  18.080460
# 15                     Jakob  59.329274  18.066006
# 16                     Jakob  59.329274  18.066006
# 17                     Jakob  59.329274  18.066006
# 18                     Jakob  59.329274  18.066006
# 19                     Jakob  59.329274  18.066006
# 20                     Jakob  59.329274  18.066006
# 21                     Jakob  59.329274  18.066006
# 22                     Jakob  59.329274  18.066006
# 23                     Jakob  59.329274  18.066006
# 24                     Jakob  59.329274  18.066006
# 25                     Jakob  59.329274  18.066006
# 26                     Jakob  59.329274  18.066006
# 27                     Jakob  59.329274  18.066006
# 28                     Jakob  59.329274  18.066006
# 29                     Jakob  59.329274  18.066006
# 30                     Jakob  59.329274  18.066006
# 31                     Jakob  59.329274  18.066006
# 32                     Klara  59.334667  18.068028
# 33                     Klara  59.334667  18.068028
# 34                     Klara  59.334667  18.068028
# 35                     Klara  59.334667  18.068028
# 36                     Klara  59.334667  18.068028
# 37                     Klara  59.334667  18.068028
# 38                     Klara  59.334667  18.068028
# 39                     Klara  59.334667  18.068028
# 40                     Klara  59.334667  18.068028
# 41                     Klara  59.334667  18.068028
# 42                     Klara  59.334667  18.068028
# 43                     Klara  59.334667  18.068028
# 47          Bakery
# 48          Bakery
# 49            Café
# 50          Bakery
# 51          Bakery
# 52          Bakery
# 53          Bakery
# 54          Bakery
# 55          Bakery
# 56          Bakery
# 57          Bakery
# 58          Bakery
# 59          Bakery
# 60          Bakery
# 61          Bakery
# 62          Bakery
# 63          Bakery
# 64     Coffee Shop
# 65          Bakery
# 66            Café
# 67          Bakery
# 68          Bakery
# 69          Bakery
# 70          Bakery
# 71          Bakery
# 72          Bakery
# 73          Bakery
# 74          Bakery
# 75          Bakery
# 76     Coffee Shop
# 77            Café
# 78          Bakery
# 79          Bakery
# 80          Bakery
# 81          Bakery
# 82    Cupcake Shop
# 83          Bakery
# 84          Bakery
# 85          Bakery
# 86          Bakery
# 87          Bakery
# 88          Bakery
# 89          Bakery
# 90          Bakery
# 91          Bakery
# 92          Bakery
# 93          Bakery
# 94     Coffee Shop
# 95          Bakery
# 96          Bakery
# 97          Bakery
# 98            Café
# 99          Bakery
# 100         Bakery
# 101         Bakery
# 102         Bakery
# 103         Bakery
# 104           Café
# 105         Bakery
# 106         Bakery
# 107           Café
# 108         Bakery
# 109         Bakery
# 110         Bakery
# 111         Bakery
# 112         Bakery
# 113         Bakery
# 114         Bakery
# 115         Bakery
# 116         Bakery
# 117         Bakery
# 118         Bakery
# 119         Bakery
# 120    Coffee Shop
# 121         Bakery
# 122         Bakery
# 123         Bakery
# 124           Café
# 125         Bakery
# 126         Bakery
# 127         Bakery
# 128         Bakery
# 129  Grocery Store
# 130         Bakery
# 131         Bakery
# 132         Bakery
# 133         Bakery
# 134         Bakery
# 135         Bakery
# 136         Bakery
# 137         Bakery
# 138         Bakery
# 139         Bakery
# 140         Bakery
# 141    Coffee Shop
# 142           Café
# 143         Bakery
# 144         Bakery
# 145         Bakery
# 146         Bakery
# 147   Cupcake Shop
# 148         Bakery
# 149         Bakery
# 150         Bakery
# 151         Bakery
# 152         Bakery
# 153         Bakery
# 154         Bakery
# 155         Bakery
# 156         Bakery
# 157         Bakery
# 158         Bakery
# 159         Bakery
# 160         Bakery
# 161         Bakery
# 162         Bakery
# 163         Bakery
# 164    Coffee Shop
# 165         Bakery
# 166         Bakery
# 167         Bakery
# 168           Café
# 169         Bakery
# 170           Café
# 171         Bakery
# 172         Bakery
# 173           Café
# 174         Bakery
# 175         Bakery
# 176         Bakery
# 177         Bakery
# 178         Bakery
# 179         Bakery
# 180         Bakery
# 181         Bakery
# 182         Bakery
# 183         Bakery
# 184         Bakery
# 185         Bakery
# 186         Bakery
# 187         Bakery
# 188           Café
# 189         Bakery
# 190         Bakery
# 191         Bakery
# 192         Bakery
# 193         Bakery
# 194         Bakery
# 195         Bakery
# 196         Bakery
# 197         Bakery
# 198           Café
# 199         Bakery
# 200         Bakery
# 201         Bakery

# %%
# Okay, let's see how many bakeries we have in Stockholm
print('There are a total of {} bakeries in Stockholm.'.format(len(df_venues.index)))
# Out:
# There are a total of 202 bakeries in Stockholm.

# %% [markdown]
# ## Analyzing the Districts in Stockholm

# %%
# Let's see how many bakeries we have in each District
df_bakery = pd.DataFrame(venues)
df_bakery.columns = ['District', 'Latitude', 'Longitude', 'Venue Name', 'Venue Latitude', 'Venue Longitude', 'Venue Category']
df_bakery['Bakery Freq'] = df_venues.groupby('District')['District'].transform('count')

#Remove columns not needed and removing duplicates
df_bakery=df_bakery.drop(df_venues.columns[[1, 2, 3, 4, 5, 5,6]], axis=1)
df_bakery=df_bakery.drop_duplicates()
df_bakery
# Out:
#                     District  Bakery Freq
# 0                 Djurgården            1
# 1                   Fredhäll            1
# 2                Gustav Vasa            7
# 9            Hedvig Eleonora            6
# 15                     Jakob           17
# 32                     Klara           18
# 50              Kristineberg            1
# 51                 Kungsholm            6
# 57            Lilla Essingen            3
# 60               Mariatorget            7
# 67         Mellersta Högalid            4
# 71       Norra Adolf Fredrik           16
# 87            Norra Johannes           12
# 99             Norra Högalid            4
# 103              Norra Sofia            7
# 110             Oscars Kyrka            2
# 112  Reimersholme-Långholmen            1
# 113               Storkyrkan           13
# 126     Stureplan-Lärkstaden           10
# 136      Södra Adolf Fredrik           16
# 152     Södra Hammarbyhamnen            1
# 153            Södra Högalid            4
# 157           Södra Johannes           12
# 169              Södra Sofia            7
# 176            Södra Station            4
# 180       Tekniska Högskolan            3
# 183          Västra Katarina            9
# 192           Västra Matteus            1
# 193           Östra Katarina            9

# %% [markdown]
# __Now, let's see how many bakeries we have per capita in each district as a basis for our clustering.__

# %%
# Merging with our first data frame to get population in each District
df_merged = pd.merge(df_bakery, df_sthlm, on = 'District')
# Add a new column with number of bakeries per person.
df_merged['Bakeries Per Capita'] = df_merged['Bakery Freq'].divide(df_merged['Population'])
df_merged
# Out:
#                    District  Bakery Freq  Population           Borough  \
# 0                Djurgården            1         788         Östermalm
# 1                  Fredhäll            1        4958       Kungsholmen
# 2               Gustav Vasa            7       12911          Norrmalm
# 3           Hedvig Eleonora            6       10387         Östermalm
# 4                     Jakob           17         201          Norrmalm
# 5                     Klara           18        1597          Norrmalm
# 6              Kristineberg            1        5572       Kungsholmen
# 7                 Kungsholm            6       18465       Kungsholmen
# 8            Lilla Essingen            3        4519       Kungsholmen
# 9               Mariatorget            7       14099  Maria-Gamla stan
# 10        Mellersta Högalid            4        9914  Maria-Gamla stan
# 11      Norra Adolf Fredrik           16        3816          Norrmalm
# 12           Norra Johannes           12        9043          Norrmalm
# 13            Norra Högalid            4       13166  Maria-Gamla stan
# 14              Norra Sofia            7        7721    Katarina-Sofia
# 15             Oscars Kyrka            2       15271         Östermalm
# 16  Reimersholme-Långholmen            1        2349  Maria-Gamla stan
# 17               Storkyrkan           13        3017  Maria-Gamla stan
# 18     Stureplan-Lärkstaden           10        8104         Östermalm
# 19      Södra Adolf Fredrik           16        3703          Norrmalm
# 20     Södra Hammarbyhamnen            1       10615    Katarina-Sofia
# 21            Södra Högalid            4        4155    Katarina-Sofia
# 22           Södra Johannes           12        2011          Norrmalm
# 23              Södra Sofia            7       11015    Katarina-Sofia
# 24            Södra Station            4        4844    Katarina-Sofia
# 25       Tekniska Högskolan            3        3442         Östermalm
# 26          Västra Katarina            9       13220    Katarina-Sofia
# 27           Västra Matteus            1       14272       Kungsholmen
# 28           Östra Katarina            9       19855    Katarina-Sofia
#
#      Latitude  Longitude  Bakeries Per Capita
# 0   59.324620  18.097800             0.001269
# 1   59.331030  18.005450             0.000202
# 2   59.342500  18.047750             0.000542
# 3   59.335240  18.080460             0.000578
# 4   59.329274  18.066006             0.084577
# 5   59.334667  18.068028             0.011271
# 6   59.336620  18.004860             0.000179
# 7   59.329010  18.048540             0.000325
# 8   59.325040  18.006770             0.000664
# 9   59.318302  18.063466             0.000496
# 10  59.317260  18.037730             0.000403
# 11  59.337890  18.060060             0.004193
# 12  59.323700  18.074492             0.001327
# 13  59.317260  18.037730             0.000304
# 14  59.312150  18.088350             0.000907
# 15  59.333300  18.092900             0.000131
# 16  59.317850  18.021540             0.000426
# 17  59.325630  18.069820             0.004309
# 18  59.335578  18.073046             0.001234
# 19  59.337890  18.060060             0.004321
# 20  59.312360  18.107480             0.000094
# 21  59.317260  18.037730             0.000963
# 22  59.323700  18.074492             0.005967
# 23  59.312150  18.088350             0.000635
# 24  59.346270  18.034670             0.000826
# 25  59.345700  18.071940             0.000872
# 26  59.316860  18.078300             0.000681
# 27  59.321946  18.030200             0.000070
# 28  59.316860  18.078300             0.000453

# %% [markdown]
# ## Clustering Districts
# __Here we use ML to cluster each district using k-means clustering.__

# %%
# set number of clusters
kclusters = 5

df_merged_clustering = df_merged.drop(df_merged.columns[[0, 1, 2, 3, 4, 5, 5,]], axis=1)


# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_merged_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([0, 4, 4, 4, 1, 3, 4, 4, 4, 4, 4, 2, 0, 4, 0, 4, 4, 2, 0, 2, 4, 0,
#        2, 4, 0, 0, 4, 4, 4], dtype=int32)

# %% [markdown]
# Let's create a new dataframe that includes the cluster for each neighborhood.

# %%
df_merged.insert(1, 'Cluster Labels', kmeans.labels_)
df_merged
# Out:
#                    District  Cluster Labels  Bakery Freq  Population  \
# 0                Djurgården               0            1         788
# 1                  Fredhäll               4            1        4958
# 2               Gustav Vasa               4            7       12911
# 3           Hedvig Eleonora               4            6       10387
# 4                     Jakob               1           17         201
# 5                     Klara               3           18        1597
# 6              Kristineberg               4            1        5572
# 7                 Kungsholm               4            6       18465
# 8            Lilla Essingen               4            3        4519
# 9               Mariatorget               4            7       14099
# 10        Mellersta Högalid               4            4        9914
# 11      Norra Adolf Fredrik               2           16        3816
# 12           Norra Johannes               0           12        9043
# 13            Norra Högalid               4            4       13166
# 14              Norra Sofia               0            7        7721
# 15             Oscars Kyrka               4            2       15271
# 16  Reimersholme-Långholmen               4            1        2349
# 17               Storkyrkan               2           13        3017
# 18     Stureplan-Lärkstaden               0           10        8104
# 19      Södra Adolf Fredrik               2           16        3703
# 20     Södra Hammarbyhamnen               4            1       10615
# 21            Södra Högalid               0            4        4155
# 22           Södra Johannes               2           12        2011
# 23              Södra Sofia               4            7       11015
# 24            Södra Station               0            4        4844
# 25       Tekniska Högskolan               0            3        3442
# 26          Västra Katarina               4            9       13220
# 27           Västra Matteus               4            1       14272
# 28           Östra Katarina               4            9       19855
#
#              Borough   Latitude  Longitude  Bakeries Per Capita
# 0          Östermalm  59.324620  18.097800             0.001269
# 1        Kungsholmen  59.331030  18.005450             0.000202
# 2           Norrmalm  59.342500  18.047750             0.000542
# 3          Östermalm  59.335240  18.080460             0.000578
# 4           Norrmalm  59.329274  18.066006             0.084577
# 5           Norrmalm  59.334667  18.068028             0.011271
# 6        Kungsholmen  59.336620  18.004860             0.000179
# 7        Kungsholmen  59.329010  18.048540             0.000325
# 8        Kungsholmen  59.325040  18.006770             0.000664
# 9   Maria-Gamla stan  59.318302  18.063466             0.000496
# 10  Maria-Gamla stan  59.317260  18.037730             0.000403
# 11          Norrmalm  59.337890  18.060060             0.004193
# 12          Norrmalm  59.323700  18.074492             0.001327
# 13  Maria-Gamla stan  59.317260  18.037730             0.000304
# 14    Katarina-Sofia  59.312150  18.088350             0.000907
# 15         Östermalm  59.333300  18.092900             0.000131
# 16  Maria-Gamla stan  59.317850  18.021540             0.000426
# 17  Maria-Gamla stan  59.325630  18.069820             0.004309
# 18         Östermalm  59.335578  18.073046             0.001234
# 19          Norrmalm  59.337890  18.060060             0.004321
# 20    Katarina-Sofia  59.312360  18.107480             0.000094
# 21    Katarina-Sofia  59.317260  18.037730             0.000963
# 22          Norrmalm  59.323700  18.074492             0.005967
# 23    Katarina-Sofia  59.312150  18.088350             0.000635
# 24    Katarina-Sofia  59.346270  18.034670             0.000826
# 25         Östermalm  59.345700  18.071940             0.000872
# 26    Katarina-Sofia  59.316860  18.078300             0.000681
# 27       Kungsholmen  59.321946  18.030200             0.000070
# 28    Katarina-Sofia  59.316860  18.078300             0.000453

# %% [markdown]
# ## Map of the Clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_merged['Latitude'], df_merged['Longitude'], df_merged['District'], df_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examine Clusters

# %% [markdown]
# Here we will examine each cluster.

# %% [markdown]
# ### Cluster 0

# %%
df_merged.loc[df_merged['Cluster Labels'] == 0]
# Out:
#                 District  Cluster Labels  Bakery Freq  Population  \
# 0             Djurgården               0            1         788
# 12        Norra Johannes               0           12        9043
# 14           Norra Sofia               0            7        7721
# 18  Stureplan-Lärkstaden               0           10        8104
# 21         Södra Högalid               0            4        4155
# 24         Södra Station               0            4        4844
# 25    Tekniska Högskolan               0            3        3442
#
#            Borough   Latitude  Longitude  Bakeries Per Capita
# 0        Östermalm  59.324620  18.097800             0.001269
# 12        Norrmalm  59.323700  18.074492             0.001327
# 14  Katarina-Sofia  59.312150  18.088350             0.000907
# 18       Östermalm  59.335578  18.073046             0.001234
# 21  Katarina-Sofia  59.317260  18.037730             0.000963
# 24  Katarina-Sofia  59.346270  18.034670             0.000826
# 25       Östermalm  59.345700  18.071940             0.000872

# %% [markdown]
# ### Cluster 1

# %%
df_merged.loc[df_merged['Cluster Labels'] == 1]
# Out:
#   District  Cluster Labels  Bakery Freq  Population   Borough   Latitude  \
# 4    Jakob               1           17         201  Norrmalm  59.329274
#
#    Longitude  Bakeries Per Capita
# 4  18.066006             0.084577

# %% [markdown]
# ### Cluster 2

# %%
df_merged.loc[df_merged['Cluster Labels'] == 2]
# Out:
#                District  Cluster Labels  Bakery Freq  Population  \
# 11  Norra Adolf Fredrik               2           16        3816
# 17           Storkyrkan               2           13        3017
# 19  Södra Adolf Fredrik               2           16        3703
# 22       Södra Johannes               2           12        2011
#
#              Borough  Latitude  Longitude  Bakeries Per Capita
# 11          Norrmalm  59.33789  18.060060             0.004193
# 17  Maria-Gamla stan  59.32563  18.069820             0.004309
# 19          Norrmalm  59.33789  18.060060             0.004321
# 22          Norrmalm  59.32370  18.074492             0.005967

# %% [markdown]
# ### Cluster 3

# %%
df_merged.loc[df_merged['Cluster Labels'] == 3]
# Out:
#   District  Cluster Labels  Bakery Freq  Population   Borough   Latitude  \
# 5    Klara               3           18        1597  Norrmalm  59.334667
#
#    Longitude  Bakeries Per Capita
# 5  18.068028             0.011271

# %% [markdown]
# ### Cluster 4

# %%
df_merged.loc[df_merged['Cluster Labels'] == 4]
# Out:
#                    District  Cluster Labels  Bakery Freq  Population  \
# 1                  Fredhäll               4            1        4958
# 2               Gustav Vasa               4            7       12911
# 3           Hedvig Eleonora               4            6       10387
# 6              Kristineberg               4            1        5572
# 7                 Kungsholm               4            6       18465
# 8            Lilla Essingen               4            3        4519
# 9               Mariatorget               4            7       14099
# 10        Mellersta Högalid               4            4        9914
# 13            Norra Högalid               4            4       13166
# 15             Oscars Kyrka               4            2       15271
# 16  Reimersholme-Långholmen               4            1        2349
# 20     Södra Hammarbyhamnen               4            1       10615
# 23              Södra Sofia               4            7       11015
# 26          Västra Katarina               4            9       13220
# 27           Västra Matteus               4            1       14272
# 28           Östra Katarina               4            9       19855
#
#              Borough   Latitude  Longitude  Bakeries Per Capita
# 1        Kungsholmen  59.331030  18.005450             0.000202
# 2           Norrmalm  59.342500  18.047750             0.000542
# 3          Östermalm  59.335240  18.080460             0.000578
# 6        Kungsholmen  59.336620  18.004860             0.000179
# 7        Kungsholmen  59.329010  18.048540             0.000325
# 8        Kungsholmen  59.325040  18.006770             0.000664
# 9   Maria-Gamla stan  59.318302  18.063466             0.000496
# 10  Maria-Gamla stan  59.317260  18.037730             0.000403
# 13  Maria-Gamla stan  59.317260  18.037730             0.000304
# 15         Östermalm  59.333300  18.092900             0.000131
# 16  Maria-Gamla stan  59.317850  18.021540             0.000426
# 20    Katarina-Sofia  59.312360  18.107480             0.000094
# 23    Katarina-Sofia  59.312150  18.088350             0.000635
# 26    Katarina-Sofia  59.316860  18.078300             0.000681
# 27       Kungsholmen  59.321946  18.030200             0.000070
# 28    Katarina-Sofia  59.316860  18.078300             0.000453

# %% [markdown]
# # Results and Discussion

# %% [markdown]
# Our analysis shows that there are over 200 bakeries in central Stockholm, with five distinct clusters of density of bakeries per capita.
# It could of course be interesting to include other venues such as cafés and bistros, since these could be competing with eachother.
# Additional data to analyze would be average income in each district, but I could not find the data.
#
# What we can see from our analysis is that there are several areas in Stockholm that could use some new bakeries - which can be found in cluster 4.

# %% [markdown]
# # Conclusion

# %% [markdown]
# For anyone interested in opening a new bakery in Stockholm, any of the districts in cluster 4 would be recommended!
